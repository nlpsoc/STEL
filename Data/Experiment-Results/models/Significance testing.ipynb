# %%
# see also: https://machinelearningmastery.com/mcnemars-test-for-machine-learning/

import pandas as pd
import numpy as np
import random as rand
from statsmodels.stats.contingency_tables import mcnemar

# %%
all_pred = pd.read_csv('STEL_single-pred-quadruple_all-models.tsv', sep='\t')

# %%
len(all_pred)
# Out:
# 1830

# %%
def sample_random(sim_str):
    pred_sim = all_pred[sim_str].copy()
    rand_ids = pred_sim.index[pred_sim == 0].tolist()
    for cur_id in rand_ids:
        pred_sim.at[cur_id] = rand.choice([1,2])
    print('Replaced {} values'.format(len(rand_ids)))
    return pred_sim
    
def no_random(sim_str_1, sim_str_2):
    tmp_all_pred = all_pred.copy()
    all_indices = tmp_all_pred.index.to_list()
    rand_ids_1 = set(tmp_all_pred.index[tmp_all_pred[sim_str_1] == 0].tolist())
    rand_ids_2 = set(tmp_all_pred.index[tmp_all_pred[sim_str_2] == 0].tolist())
    rand_ids = list(rand_ids_1.union(rand_ids_2))
    # print(rand_ids)
    no_random_ids = [cur_id for cur_id in all_indices if cur_id not in rand_ids]
    tmp_all_pred = tmp_all_pred.iloc[no_random_ids]
    correct_preds = all_pred['Correct Alternative'][no_random_ids]
    # tmp_all_pred.reset_index(drop=True, inplace=True)
    # tmp_all_pred.sort_index(inplace=True)
    #for cur_id in no_random_ids:
    #    tmp_all_pred = tmp_all_pred.drop(cur_id)
    # print(tmp_all_pred[sim_str_1])
    # print(tmp_all_pred[sim_str_2])
    print('Dropped {} values'.format(len(rand_ids)))
    tmp_all_pred[sim_str_1] == tmp_all_pred[sim_str_2]
    return tmp_all_pred[sim_str_1], tmp_all_pred[sim_str_2], correct_preds
    
def _calc_sig_from_df(pred_sim_1, pred_sim_2, correct_predictions=all_pred['Correct Alternative']):    
    p1_correctness = pred_sim_1 == correct_predictions
    p2_correctness = pred_sim_2 == correct_predictions
    yes_yes = p1_correctness & p2_correctness
    nbr_yes_yes = yes_yes[yes_yes == True].sum()
    no_no = ~p1_correctness & ~p2_correctness
    nbr_no_no = no_no[no_no == True].sum()
    yes_no = p1_correctness & ~p2_correctness
    nbr_yes_no = yes_no[yes_no == True].sum()
    no_yes = ~p1_correctness & p2_correctness
    nbr_no_yes = no_yes[no_yes == True].sum()
    table = [[nbr_yes_yes, nbr_yes_no], [nbr_no_yes, nbr_no_no]]
    result = mcnemar(table, exact=True)
    print('statistic=%.3f, p-value=%.10f' % (result.statistic, result.pvalue))
    return result.pvalue
    
def significance_testing(sim_str_1, sim_str_2):
    pred_sim_1 = sample_random(sim_str_1)
    pred_sim_2 = sample_random(sim_str_2)
    return _calc_sig_from_df(pred_sim_1, pred_sim_2)

def sig_test_no_random(sim_str_1, sim_str_2):
    pred_sim_1, pred_sim_2, correct_preds = no_random(sim_str_1, sim_str_2)
    print('working with length {}'.format(len(pred_sim_1)))
    return _calc_sig_from_df(pred_sim_1, pred_sim_2, correct_preds)

def mean_sig_test(sim_str_1, sim_str_2):
    p_values = []
    for _ in range(100):
        p_values.append(significance_testing(sim_str_1, sim_str_2))
    mean_p_value = np.mean(p_values)
    print('p-value=%.10f' % (mean_p_value))

# %%
significance_testing('CasedBertSimilarity', 'UncasedBertSimilarity')
# Out:
# Replaced 0 values
# Replaced 0 values
# statistic=206.000, p-value=0.0084887766
# 0.00848877655387761

# %%
significance_testing('BERTCasedNextSentenceSimilarity', 'BERTUncasedNextSentenceSimilarity')
# Out:
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0001224951
# 0.0001224950520884254

# %%
sig_test_no_random('BERTCasedNextSentenceSimilarity', 'BERTUncasedNextSentenceSimilarity')
# Out:
# Dropped 199 values
# working with length 1631
# statistic=218.000, p-value=0.0002653185
# 0.00026531846381390114

# %%
mean_sig_test('BERTCasedNextSentenceSimilarity', 'BERTUncasedNextSentenceSimilarity')
# Out:
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0001289105
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000971075
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0000659569
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0001224951
# Replaced 35 values
# Replaced 187 values
# statistic=271.000, p-value=0.0007815768
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000165169
# Replaced 35 values
# Replaced 187 values
# statistic=255.000, p-value=0.0000159997
# Replaced 35 values
# Replaced 187 values
# statistic=251.000, p-value=0.0000140590
# Replaced 35 values
# Replaced 187 values
# statistic=251.000, p-value=0.0000323531
# Replaced 35 values
# Replaced 187 values
# statistic=265.000, p-value=0.0000904162
# Replaced 35 values
# Replaced 187 values
# statistic=266.000, p-value=0.0003512641
# Replaced 35 values
# Replaced 187 values
# statistic=268.000, p-value=0.0001778535
# Replaced 35 values
# Replaced 187 values
# statistic=267.000, p-value=0.0005479531
# Replaced 35 values
# Replaced 187 values
# statistic=262.000, p-value=0.0002777846
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0001193786
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0001426043
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0001462394
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000710657
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0001193786
# Replaced 35 values
# Replaced 187 values
# statistic=252.000, p-value=0.0000103388
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0000398172
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0000677869
# Replaced 35 values
# Replaced 187 values
# statistic=257.000, p-value=0.0000121922
# Replaced 35 values
# Replaced 187 values
# statistic=262.000, p-value=0.0000974832
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0001107058
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0000409847
# Replaced 35 values
# Replaced 187 values
# statistic=257.000, p-value=0.0002129697
# Replaced 35 values
# Replaced 187 values
# statistic=252.000, p-value=0.0000087084
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0002590214
# Replaced 35 values
# Replaced 187 values
# statistic=262.000, p-value=0.0000835694
# Replaced 35 values
# Replaced 187 values
# statistic=268.000, p-value=0.0003670403
# Replaced 35 values
# Replaced 187 values
# statistic=262.000, p-value=0.0002399867
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0000193061
# Replaced 35 values
# Replaced 187 values
# statistic=263.000, p-value=0.0003285171
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0000398172
# Replaced 35 values
# Replaced 187 values
# statistic=264.000, p-value=0.0000403038
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0001193786
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000070715
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0000296831
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000710657
# Replaced 35 values
# Replaced 187 values
# statistic=268.000, p-value=0.0001320917
# Replaced 35 values
# Replaced 187 values
# statistic=255.000, p-value=0.0000159997
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0000677869
# Replaced 35 values
# Replaced 187 values
# statistic=257.000, p-value=0.0000237340
# Replaced 35 values
# Replaced 187 values
# statistic=255.000, p-value=0.0000159997
# Replaced 35 values
# Replaced 187 values
# statistic=264.000, p-value=0.0004468929
# Replaced 35 values
# Replaced 187 values
# statistic=248.000, p-value=0.0000348009
# Replaced 35 values
# Replaced 187 values
# statistic=255.000, p-value=0.0000691294
# Replaced 35 values
# Replaced 187 values
# statistic=266.000, p-value=0.0001256907
# Replaced 35 values
# Replaced 187 values
# statistic=262.000, p-value=0.0001322110
# Replaced 35 values
# Replaced 187 values
# statistic=263.000, p-value=0.0001355742
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000195085
# Replaced 35 values
# Replaced 187 values
# statistic=265.000, p-value=0.0001225788
# Replaced 35 values
# Replaced 187 values
# statistic=262.000, p-value=0.0005675124
# Replaced 35 values
# Replaced 187 values
# statistic=269.000, p-value=0.0003751150
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0002651703
# Replaced 35 values
# Replaced 187 values
# statistic=254.000, p-value=0.0000255229
# Replaced 35 values
# Replaced 187 values
# statistic=269.000, p-value=0.0006554585
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0000369876
# Replaced 35 values
# Replaced 187 values
# statistic=269.000, p-value=0.0012839707
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0003139521
# Replaced 35 values
# Replaced 187 values
# statistic=252.000, p-value=0.0000043372
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0000314891
# Replaced 35 values
# Replaced 187 values
# statistic=263.000, p-value=0.0000147592
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0000877146
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0000338884
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0000433995
# Replaced 35 values
# Replaced 187 values
# statistic=272.000, p-value=0.0006958701
# Replaced 35 values
# Replaced 187 values
# statistic=266.000, p-value=0.0010633040
# Replaced 35 values
# Replaced 187 values
# statistic=264.000, p-value=0.0001026656
# Replaced 35 values
# Replaced 187 values
# statistic=267.000, p-value=0.0002012486
# Replaced 35 values
# Replaced 187 values
# statistic=265.000, p-value=0.0001919169
# Replaced 35 values
# Replaced 187 values
# statistic=263.000, p-value=0.0000537784
# Replaced 35 values
# Replaced 187 values
# statistic=264.000, p-value=0.0000646386
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0000494593
# Replaced 35 values
# Replaced 187 values
# statistic=265.000, p-value=0.0002975118
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000139690
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0000409847
# Replaced 35 values
# Replaced 187 values
# statistic=264.000, p-value=0.0000472273
# Replaced 35 values
# Replaced 187 values
# statistic=268.000, p-value=0.0001778535
# Replaced 35 values
# Replaced 187 values
# statistic=259.000, p-value=0.0000252205
# Replaced 35 values
# Replaced 187 values
# statistic=266.000, p-value=0.0000682065
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0000433995
# Replaced 35 values
# Replaced 187 values
# statistic=262.000, p-value=0.0001537161
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0000158624
# Replaced 35 values
# Replaced 187 values
# statistic=254.000, p-value=0.0000573685
# Replaced 35 values
# Replaced 187 values
# statistic=257.000, p-value=0.0000170472
# Replaced 35 values
# Replaced 187 values
# statistic=253.000, p-value=0.0000150043
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0000579339
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0000696556
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0000595574
# Replaced 35 values
# Replaced 187 values
# statistic=266.000, p-value=0.0001695170
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000271278
# Replaced 35 values
# Replaced 187 values
# statistic=274.000, p-value=0.0004797572
# Replaced 35 values
# Replaced 187 values
# statistic=257.000, p-value=0.0000853930
# Replaced 35 values
# Replaced 187 values
# statistic=261.000, p-value=0.0001107058
# Replaced 35 values
# Replaced 187 values
# statistic=254.000, p-value=0.0000300767
# Replaced 35 values
# Replaced 187 values
# statistic=256.000, p-value=0.0000230172
# Replaced 35 values
# Replaced 187 values
# statistic=258.000, p-value=0.0000467326
# Replaced 35 values
# Replaced 187 values
# statistic=260.000, p-value=0.0000494593
# p-value=0.0001521112

# %%
significance_testing('BERTCasedNextSentenceSimilarity', 'RobertaSimilarity')
# Out:
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000000
# 1.7901220789015757e-11

# %%
sig_test_no_random('BERTCasedNextSentenceSimilarity', 'RobertaSimilarity')
mean_sig_test('BERTCasedNextSentenceSimilarity', 'RobertaSimilarity')
# Out:
# Dropped 35 values
# working with length 1795
# statistic=286.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=298.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=298.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000002
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000002
# Replaced 35 values
# Replaced 0 values
# statistic=291.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=298.000, p-value=0.0000000002
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=298.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000002
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=291.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=298.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=292.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=297.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=291.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000003
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=298.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=291.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=298.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=293.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=294.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=295.000, p-value=0.0000000000
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# Replaced 35 values
# Replaced 0 values
# statistic=296.000, p-value=0.0000000001
# p-value=0.0000000001

# %%
significance_testing('MpnetSentenceBertSimilarity', 'ParaMpnetSentenceBertSimilarity')
# Out:
# Replaced 0 values
# Replaced 0 values
# statistic=272.000, p-value=0.0000003603
# 3.602681412702784e-07

# %%
significance_testing('CasedBertSimilarity', 'RobertaSimilarity')
# Out:
# Replaced 0 values
# Replaced 0 values
# statistic=214.000, p-value=0.0000000000
# 6.804315534243815e-29

# %%
sig_test_no_random('LIWCStyleSimilarity','LIWCSimilarity')
mean_sig_test('LIWCStyleSimilarity','LIWCSimilarity')
# Out:
# Dropped 1148 values
# working with length 682
# statistic=143.000, p-value=0.9530249959
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.1097733700
# Replaced 1141 values
# Replaced 158 values
# statistic=379.000, p-value=0.0256281951
# Replaced 1141 values
# Replaced 158 values
# statistic=403.000, p-value=0.0165202446
# Replaced 1141 values
# Replaced 158 values
# statistic=396.000, p-value=0.0204267185
# Replaced 1141 values
# Replaced 158 values
# statistic=389.000, p-value=0.0069618464
# Replaced 1141 values
# Replaced 158 values
# statistic=420.000, p-value=0.1574953770
# Replaced 1141 values
# Replaced 158 values
# statistic=394.000, p-value=0.0499666530
# Replaced 1141 values
# Replaced 158 values
# statistic=390.000, p-value=0.0042623768
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0071612224
# Replaced 1141 values
# Replaced 158 values
# statistic=412.000, p-value=0.0684890877
# Replaced 1141 values
# Replaced 158 values
# statistic=384.000, p-value=0.0023591249
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0351760099
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0355991184
# Replaced 1141 values
# Replaced 158 values
# statistic=388.000, p-value=0.0210425285
# Replaced 1141 values
# Replaced 158 values
# statistic=389.000, p-value=0.0016211597
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0119901684
# Replaced 1141 values
# Replaced 158 values
# statistic=388.000, p-value=0.0122390435
# Replaced 1141 values
# Replaced 158 values
# statistic=395.000, p-value=0.0014014300
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0958385791
# Replaced 1141 values
# Replaced 158 values
# statistic=375.000, p-value=0.0159191365
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0279990043
# Replaced 1141 values
# Replaced 158 values
# statistic=396.000, p-value=0.0119215137
# Replaced 1141 values
# Replaced 158 values
# statistic=389.000, p-value=0.0123414636
# Replaced 1141 values
# Replaced 158 values
# statistic=412.000, p-value=0.0317759217
# Replaced 1141 values
# Replaced 158 values
# statistic=401.000, p-value=0.0058135310
# Replaced 1141 values
# Replaced 158 values
# statistic=397.000, p-value=0.1465315275
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0894329316
# Replaced 1141 values
# Replaced 158 values
# statistic=409.000, p-value=0.1722855808
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0045751987
# Replaced 1141 values
# Replaced 158 values
# statistic=406.000, p-value=0.0950708526
# Replaced 1141 values
# Replaced 158 values
# statistic=393.000, p-value=0.0361312661
# Replaced 1141 values
# Replaced 158 values
# statistic=414.000, p-value=0.0797277965
# Replaced 1141 values
# Replaced 158 values
# statistic=403.000, p-value=0.0326281005
# Replaced 1141 values
# Replaced 158 values
# statistic=420.000, p-value=0.1390844175
# Replaced 1141 values
# Replaced 158 values
# statistic=399.000, p-value=0.0644055502
# Replaced 1141 values
# Replaced 158 values
# statistic=397.000, p-value=0.0224327754
# Replaced 1141 values
# Replaced 158 values
# statistic=385.000, p-value=0.0373357559
# Replaced 1141 values
# Replaced 158 values
# statistic=420.000, p-value=0.1574953770
# Replaced 1141 values
# Replaced 158 values
# statistic=409.000, p-value=0.4687376120
# Replaced 1141 values
# Replaced 158 values
# statistic=399.000, p-value=0.0990291212
# Replaced 1141 values
# Replaced 158 values
# statistic=395.000, p-value=0.0089222941
# Replaced 1141 values
# Replaced 158 values
# statistic=389.000, p-value=0.0084552529
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0451590425
# Replaced 1141 values
# Replaced 158 values
# statistic=382.000, p-value=0.0087359592
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0143607447
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0072599840
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0208901290
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0045751987
# Replaced 1141 values
# Replaced 158 values
# statistic=407.000, p-value=0.0362363562
# Replaced 1141 values
# Replaced 158 values
# statistic=416.000, p-value=0.2621119807
# Replaced 1141 values
# Replaced 158 values
# statistic=399.000, p-value=0.0405787965
# Replaced 1141 values
# Replaced 158 values
# statistic=395.000, p-value=0.0017449187
# Replaced 1141 values
# Replaced 158 values
# statistic=391.000, p-value=0.1027498560
# Replaced 1141 values
# Replaced 158 values
# statistic=386.000, p-value=0.0109578268
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0935342666
# Replaced 1141 values
# Replaced 158 values
# statistic=399.000, p-value=0.0745997471
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0576736219
# Replaced 1141 values
# Replaced 158 values
# statistic=427.000, p-value=0.6836344532
# Replaced 1141 values
# Replaced 158 values
# statistic=390.000, p-value=0.0093887777
# Replaced 1141 values
# Replaced 158 values
# statistic=390.000, p-value=0.0063701179
# Replaced 1141 values
# Replaced 158 values
# statistic=375.000, p-value=0.0029306231
# Replaced 1141 values
# Replaced 158 values
# statistic=393.000, p-value=0.0010929347
# Replaced 1141 values
# Replaced 158 values
# statistic=383.000, p-value=0.0048602896
# Replaced 1141 values
# Replaced 158 values
# statistic=412.000, p-value=0.1042034465
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0703283418
# Replaced 1141 values
# Replaced 158 values
# statistic=381.000, p-value=0.0018294390
# Replaced 1141 values
# Replaced 158 values
# statistic=380.000, p-value=0.0004000579
# Replaced 1141 values
# Replaced 158 values
# statistic=393.000, p-value=0.0237775099
# Replaced 1141 values
# Replaced 158 values
# statistic=388.000, p-value=0.0046228135
# Replaced 1141 values
# Replaced 158 values
# statistic=396.000, p-value=0.0171299585
# Replaced 1141 values
# Replaced 158 values
# statistic=418.000, p-value=0.0755809147
# Replaced 1141 values
# Replaced 158 values
# statistic=382.000, p-value=0.0018522548
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0310087589
# Replaced 1141 values
# Replaced 158 values
# statistic=396.000, p-value=0.0339151643
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0330818884
# Replaced 1141 values
# Replaced 158 values
# statistic=377.000, p-value=0.0041144208
# Replaced 1141 values
# Replaced 158 values
# statistic=409.000, p-value=0.0110317025
# Replaced 1141 values
# Replaced 158 values
# statistic=401.000, p-value=0.0194063055
# Replaced 1141 values
# Replaced 158 values
# statistic=423.000, p-value=0.1236754369
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0075339148
# Replaced 1141 values
# Replaced 158 values
# statistic=383.000, p-value=0.0053792633
# Replaced 1141 values
# Replaced 158 values
# statistic=397.000, p-value=0.0289290879
# Replaced 1141 values
# Replaced 158 values
# statistic=398.000, p-value=0.0316315494
# Replaced 1141 values
# Replaced 158 values
# statistic=426.000, p-value=0.6832887909
# Replaced 1141 values
# Replaced 158 values
# statistic=396.000, p-value=0.0467243794
# Replaced 1141 values
# Replaced 158 values
# statistic=396.000, p-value=0.0204267185
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0672302657
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0256113853
# Replaced 1141 values
# Replaced 158 values
# statistic=383.000, p-value=0.0154895451
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0659734498
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0043519408
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0019690329
# Replaced 1141 values
# Replaced 158 values
# statistic=394.000, p-value=0.1647150364
# Replaced 1141 values
# Replaced 158 values
# statistic=426.000, p-value=0.1508114353
# Replaced 1141 values
# Replaced 158 values
# statistic=403.000, p-value=0.0071943835
# Replaced 1141 values
# Replaced 158 values
# statistic=412.000, p-value=0.1737818160
# Replaced 1141 values
# Replaced 158 values
# statistic=413.000, p-value=0.0739373610
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0033566839
# Replaced 1141 values
# Replaced 158 values
# statistic=407.000, p-value=0.0954547653
# Replaced 1141 values
# Replaced 158 values
# statistic=414.000, p-value=0.2904645328
# p-value=0.0646166361

# %%
sig_test_no_random('LIWCStyleSimilarity', 'LIWCFunctionSimilarity')
mean_sig_test('LIWCStyleSimilarity', 'LIWCFunctionSimilarity')
# Out:
# Dropped 1232 values
# working with length 598
# statistic=135.000, p-value=0.1460711812
# Replaced 1141 values
# Replaced 508 values
# statistic=450.000, p-value=0.2269926368
# Replaced 1141 values
# Replaced 508 values
# statistic=438.000, p-value=0.2464553574
# Replaced 1141 values
# Replaced 508 values
# statistic=434.000, p-value=0.1282862209
# Replaced 1141 values
# Replaced 508 values
# statistic=436.000, p-value=0.2199750031
# Replaced 1141 values
# Replaced 508 values
# statistic=448.000, p-value=0.2023709395
# Replaced 1141 values
# Replaced 508 values
# statistic=439.000, p-value=0.5478621333
# Replaced 1141 values
# Replaced 508 values
# statistic=435.000, p-value=0.3675958666
# Replaced 1141 values
# Replaced 508 values
# statistic=449.000, p-value=0.3093756622
# Replaced 1141 values
# Replaced 508 values
# statistic=453.000, p-value=0.6922428765
# Replaced 1141 values
# Replaced 508 values
# statistic=441.000, p-value=0.6402048627
# Replaced 1141 values
# Replaced 508 values
# statistic=451.000, p-value=0.2807418579
# Replaced 1141 values
# Replaced 508 values
# statistic=433.000, p-value=0.7868329660
# Replaced 1141 values
# Replaced 508 values
# statistic=429.000, p-value=0.0299468284
# Replaced 1141 values
# Replaced 508 values
# statistic=417.000, p-value=0.0752520781
# Replaced 1141 values
# Replaced 508 values
# statistic=423.000, p-value=0.2954647465
# Replaced 1141 values
# Replaced 508 values
# statistic=437.000, p-value=0.1466207393
# Replaced 1141 values
# Replaced 508 values
# statistic=437.000, p-value=0.2329558595
# Replaced 1141 values
# Replaced 508 values
# statistic=434.000, p-value=0.1845720000
# Replaced 1141 values
# Replaced 508 values
# statistic=435.000, p-value=0.3337136962
# Replaced 1141 values
# Replaced 508 values
# statistic=451.000, p-value=0.6438750691
# Replaced 1141 values
# Replaced 508 values
# statistic=452.000, p-value=0.2279820321
# Replaced 1141 values
# Replaced 508 values
# statistic=430.000, p-value=0.2049972678
# Replaced 1141 values
# Replaced 508 values
# statistic=402.000, p-value=0.0032095285
# Replaced 1141 values
# Replaced 508 values
# statistic=408.000, p-value=0.0099771380
# Replaced 1141 values
# Replaced 508 values
# statistic=432.000, p-value=0.3159622952
# Replaced 1141 values
# Replaced 508 values
# statistic=417.000, p-value=0.0415034163
# Replaced 1141 values
# Replaced 508 values
# statistic=428.000, p-value=0.1712187097
# Replaced 1141 values
# Replaced 508 values
# statistic=440.000, p-value=0.5932108456
# Replaced 1141 values
# Replaced 508 values
# statistic=441.000, p-value=0.2350010982
# Replaced 1141 values
# Replaced 508 values
# statistic=448.000, p-value=0.1041591023
# Replaced 1141 values
# Replaced 508 values
# statistic=427.000, p-value=0.1422023000
# Replaced 1141 values
# Replaced 508 values
# statistic=436.000, p-value=0.2324423311
# Replaced 1141 values
# Replaced 508 values
# statistic=452.000, p-value=0.5535543693
# Replaced 1141 values
# Replaced 508 values
# statistic=452.000, p-value=0.8424415891
# Replaced 1141 values
# Replaced 508 values
# statistic=428.000, p-value=0.2039876354
# Replaced 1141 values
# Replaced 508 values
# statistic=430.000, p-value=0.1721714995
# Replaced 1141 values
# Replaced 508 values
# statistic=431.000, p-value=0.0979202139
# Replaced 1141 values
# Replaced 508 values
# statistic=453.000, p-value=0.5539834334
# Replaced 1141 values
# Replaced 508 values
# statistic=428.000, p-value=0.2546721209
# Replaced 1141 values
# Replaced 508 values
# statistic=443.000, p-value=0.4265386921
# Replaced 1141 values
# Replaced 508 values
# statistic=428.000, p-value=0.0637761159
# Replaced 1141 values
# Replaced 508 values
# statistic=456.000, p-value=0.9736155422
# Replaced 1141 values
# Replaced 508 values
# statistic=441.000, p-value=0.5487519588
# Replaced 1141 values
# Replaced 508 values
# statistic=441.000, p-value=0.2104945203
# Replaced 1141 values
# Replaced 508 values
# statistic=423.000, p-value=0.1404231421
# Replaced 1141 values
# Replaced 508 values
# statistic=418.000, p-value=0.0996707246
# Replaced 1141 values
# Replaced 508 values
# statistic=408.000, p-value=0.1425254122
# Replaced 1141 values
# Replaced 508 values
# statistic=435.000, p-value=0.2723860751
# Replaced 1141 values
# Replaced 508 values
# statistic=443.000, p-value=0.6409479621
# Replaced 1141 values
# Replaced 508 values
# statistic=413.000, p-value=0.0793856344
# Replaced 1141 values
# Replaced 508 values
# statistic=412.000, p-value=0.0436473941
# Replaced 1141 values
# Replaced 508 values
# statistic=419.000, p-value=0.0814389494
# Replaced 1141 values
# Replaced 508 values
# statistic=444.000, p-value=0.4660865951
# Replaced 1141 values
# Replaced 508 values
# statistic=442.000, p-value=0.1994638882
# Replaced 1141 values
# Replaced 508 values
# statistic=437.000, p-value=0.7117385596
# Replaced 1141 values
# Replaced 508 values
# statistic=463.000, p-value=0.7686431035
# Replaced 1141 values
# Replaced 508 values
# statistic=451.000, p-value=0.7909869334
# Replaced 1141 values
# Replaced 508 values
# statistic=438.000, p-value=0.2334684987
# Replaced 1141 values
# Replaced 508 values
# statistic=423.000, p-value=0.1236754369
# Replaced 1141 values
# Replaced 508 values
# statistic=427.000, p-value=0.1920835068
# Replaced 1141 values
# Replaced 508 values
# statistic=451.000, p-value=0.6916054700
# Replaced 1141 values
# Replaced 508 values
# statistic=432.000, p-value=0.3003681802
# Replaced 1141 values
# Replaced 508 values
# statistic=447.000, p-value=0.3239410856
# Replaced 1141 values
# Replaced 508 values
# statistic=434.000, p-value=0.4030978029
# Replaced 1141 values
# Replaced 508 values
# statistic=462.000, p-value=0.3644095531
# Replaced 1141 values
# Replaced 508 values
# statistic=436.000, p-value=0.0425419038
# Replaced 1141 values
# Replaced 508 values
# statistic=427.000, p-value=0.3993813811
# Replaced 1141 values
# Replaced 508 values
# statistic=438.000, p-value=0.3519881218
# Replaced 1141 values
# Replaced 508 values
# statistic=430.000, p-value=0.1266138720
# Replaced 1141 values
# Replaced 508 values
# statistic=420.000, p-value=0.0360817761
# Replaced 1141 values
# Replaced 508 values
# statistic=442.000, p-value=0.1580471836
# Replaced 1141 values
# Replaced 508 values
# statistic=451.000, p-value=0.8422706549
# Replaced 1141 values
# Replaced 508 values
# statistic=436.000, p-value=0.0815072212
# Replaced 1141 values
# Replaced 508 values
# statistic=448.000, p-value=0.7903114471
# Replaced 1141 values
# Replaced 508 values
# statistic=454.000, p-value=0.7168807892
# Replaced 1141 values
# Replaced 508 values
# statistic=440.000, p-value=0.3879750143
# Replaced 1141 values
# Replaced 508 values
# statistic=426.000, p-value=0.0782134455
# Replaced 1141 values
# Replaced 508 values
# statistic=458.000, p-value=0.6938192794
# Replaced 1141 values
# Replaced 508 values
# statistic=428.000, p-value=0.4994743833
# Replaced 1141 values
# Replaced 508 values
# statistic=425.000, p-value=0.0210279769
# Replaced 1141 values
# Replaced 508 values
# statistic=445.000, p-value=0.1412848056
# Replaced 1141 values
# Replaced 508 values
# statistic=427.000, p-value=0.0106228199
# Replaced 1141 values
# Replaced 508 values
# statistic=441.000, p-value=0.2480056376
# Replaced 1141 values
# Replaced 508 values
# statistic=431.000, p-value=0.2298612902
# Replaced 1141 values
# Replaced 508 values
# statistic=439.000, p-value=0.8664630973
# Replaced 1141 values
# Replaced 508 values
# statistic=450.000, p-value=1.0000000000
# Replaced 1141 values
# Replaced 508 values
# statistic=438.000, p-value=0.0940464810
# Replaced 1141 values
# Replaced 508 values
# statistic=432.000, p-value=0.0449491988
# Replaced 1141 values
# Replaced 508 values
# statistic=429.000, p-value=0.4192991880
# Replaced 1141 values
# Replaced 508 values
# statistic=463.000, p-value=0.4952287478
# Replaced 1141 values
# Replaced 508 values
# statistic=466.000, p-value=0.5594516469
# Replaced 1141 values
# Replaced 508 values
# statistic=417.000, p-value=0.0302036788
# Replaced 1141 values
# Replaced 508 values
# statistic=448.000, p-value=0.4482963985
# Replaced 1141 values
# Replaced 508 values
# statistic=422.000, p-value=0.0173758378
# Replaced 1141 values
# Replaced 508 values
# statistic=429.000, p-value=0.0553913607
# Replaced 1141 values
# Replaced 508 values
# statistic=449.000, p-value=0.7153969919
# Replaced 1141 values
# Replaced 508 values
# statistic=430.000, p-value=0.2842352202
# Replaced 1141 values
# Replaced 508 values
# statistic=434.000, p-value=0.7359184704
# Replaced 1141 values
# Replaced 508 values
# statistic=444.000, p-value=0.6413177931
# Replaced 1141 values
# Replaced 508 values
# statistic=424.000, p-value=0.1163281685
# p-value=0.3322491635

# %%
sig_test_no_random('LIWCFunctionSimilarity','LIWCSimilarity')
mean_sig_test('LIWCStyleSimilarity','LIWCSimilarity')
# Out:
# Dropped 547 values
# working with length 1283
# statistic=259.000, p-value=0.2653829318
# Replaced 1141 values
# Replaced 158 values
# statistic=406.000, p-value=0.0456555344
# Replaced 1141 values
# Replaced 158 values
# statistic=393.000, p-value=0.0199891127
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0236131913
# Replaced 1141 values
# Replaced 158 values
# statistic=384.000, p-value=0.0223135709
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0058828755
# Replaced 1141 values
# Replaced 158 values
# statistic=398.000, p-value=0.0291162714
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0043519408
# Replaced 1141 values
# Replaced 158 values
# statistic=384.000, p-value=0.0402616963
# Replaced 1141 values
# Replaced 158 values
# statistic=380.000, p-value=0.0094476897
# Replaced 1141 values
# Replaced 158 values
# statistic=394.000, p-value=0.0036212179
# Replaced 1141 values
# Replaced 158 values
# statistic=406.000, p-value=0.0306273171
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0050639515
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0119901684
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0208901290
# Replaced 1141 values
# Replaced 158 values
# statistic=396.000, p-value=0.0287422900
# Replaced 1141 values
# Replaced 158 values
# statistic=377.000, p-value=0.0024186034
# Replaced 1141 values
# Replaced 158 values
# statistic=387.000, p-value=0.0024436286
# Replaced 1141 values
# Replaced 158 values
# statistic=397.000, p-value=0.0370132895
# Replaced 1141 values
# Replaced 158 values
# statistic=413.000, p-value=0.3917414927
# Replaced 1141 values
# Replaced 158 values
# statistic=412.000, p-value=0.1443798510
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0653458551
# Replaced 1141 values
# Replaced 158 values
# statistic=406.000, p-value=0.1244212825
# Replaced 1141 values
# Replaced 158 values
# statistic=400.000, p-value=0.0249390115
# Replaced 1141 values
# Replaced 158 values
# statistic=400.000, p-value=0.0376784762
# Replaced 1141 values
# Replaced 158 values
# statistic=395.000, p-value=0.0365715692
# Replaced 1141 values
# Replaced 158 values
# statistic=411.000, p-value=0.0844507388
# Replaced 1141 values
# Replaced 158 values
# statistic=390.000, p-value=0.0038467177
# Replaced 1141 values
# Replaced 158 values
# statistic=390.000, p-value=0.0664058009
# Replaced 1141 values
# Replaced 158 values
# statistic=403.000, p-value=0.0300578837
# Replaced 1141 values
# Replaced 158 values
# statistic=414.000, p-value=0.0554372634
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0023271358
# Replaced 1141 values
# Replaced 158 values
# statistic=405.000, p-value=0.1085380472
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0336336512
# Replaced 1141 values
# Replaced 158 values
# statistic=401.000, p-value=0.0230611824
# Replaced 1141 values
# Replaced 158 values
# statistic=391.000, p-value=0.0028448301
# Replaced 1141 values
# Replaced 158 values
# statistic=376.000, p-value=0.0000544264
# Replaced 1141 values
# Replaced 158 values
# statistic=381.000, p-value=0.0238311380
# Replaced 1141 values
# Replaced 158 values
# statistic=398.000, p-value=0.0030738552
# Replaced 1141 values
# Replaced 158 values
# statistic=400.000, p-value=0.0210158413
# Replaced 1141 values
# Replaced 158 values
# statistic=389.000, p-value=0.0016211597
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0216563067
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0213127883
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.1309756030
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0763078339
# Replaced 1141 values
# Replaced 158 values
# statistic=413.000, p-value=0.4919741358
# Replaced 1141 values
# Replaced 158 values
# statistic=400.000, p-value=0.0994280133
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0298688103
# Replaced 1141 values
# Replaced 158 values
# statistic=382.000, p-value=0.0020666226
# Replaced 1141 values
# Replaced 158 values
# statistic=391.000, p-value=0.0007556131
# Replaced 1141 values
# Replaced 158 values
# statistic=413.000, p-value=0.4106881509
# Replaced 1141 values
# Replaced 158 values
# statistic=400.000, p-value=0.0696733928
# Replaced 1141 values
# Replaced 158 values
# statistic=405.000, p-value=0.0946868438
# Replaced 1141 values
# Replaced 158 values
# statistic=395.000, p-value=0.0155458966
# Replaced 1141 values
# Replaced 158 values
# statistic=412.000, p-value=0.0192415025
# Replaced 1141 values
# Replaced 158 values
# statistic=394.000, p-value=0.1113533799
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0285642240
# Replaced 1141 values
# Replaced 158 values
# statistic=386.000, p-value=0.0292785223
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.1968389023
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0351760099
# Replaced 1141 values
# Replaced 158 values
# statistic=415.000, p-value=0.5367593981
# Replaced 1141 values
# Replaced 158 values
# statistic=373.000, p-value=0.0020648669
# Replaced 1141 values
# Replaced 158 values
# statistic=403.000, p-value=0.0196859915
# Replaced 1141 values
# Replaced 158 values
# statistic=398.000, p-value=0.0267775518
# Replaced 1141 values
# Replaced 158 values
# statistic=391.000, p-value=0.0164908180
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0304480302
# Replaced 1141 values
# Replaced 158 values
# statistic=397.000, p-value=0.0188516782
# Replaced 1141 values
# Replaced 158 values
# statistic=382.000, p-value=0.0096195781
# Replaced 1141 values
# Replaced 158 values
# statistic=385.000, p-value=0.0060673142
# Replaced 1141 values
# Replaced 158 values
# statistic=411.000, p-value=0.2070345259
# Replaced 1141 values
# Replaced 158 values
# statistic=373.000, p-value=0.0010488678
# Replaced 1141 values
# Replaced 158 values
# statistic=407.000, p-value=0.0283838667
# Replaced 1141 values
# Replaced 158 values
# statistic=389.000, p-value=0.0449227899
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.4475581196
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0187043714
# Replaced 1141 values
# Replaced 158 values
# statistic=389.000, p-value=0.0324608854
# Replaced 1141 values
# Replaced 158 values
# statistic=394.000, p-value=0.0036212179
# Replaced 1141 values
# Replaced 158 values
# statistic=391.000, p-value=0.0064316310
# Replaced 1141 values
# Replaced 158 values
# statistic=373.000, p-value=0.0088581827
# Replaced 1141 values
# Replaced 158 values
# statistic=398.000, p-value=0.0594650180
# Replaced 1141 values
# Replaced 158 values
# statistic=398.000, p-value=0.0145416032
# Replaced 1141 values
# Replaced 158 values
# statistic=398.000, p-value=0.0640924179
# Replaced 1141 values
# Replaced 158 values
# statistic=405.000, p-value=0.0280242624
# Replaced 1141 values
# Replaced 158 values
# statistic=378.000, p-value=0.0041592408
# Replaced 1141 values
# Replaced 158 values
# statistic=385.000, p-value=0.0073935511
# Replaced 1141 values
# Replaced 158 values
# statistic=395.000, p-value=0.0089222941
# Replaced 1141 values
# Replaced 158 values
# statistic=395.000, p-value=0.0202804432
# Replaced 1141 values
# Replaced 158 values
# statistic=428.000, p-value=0.1612429952
# Replaced 1141 values
# Replaced 158 values
# statistic=412.000, p-value=0.0591408003
# Replaced 1141 values
# Replaced 158 values
# statistic=402.000, p-value=0.0703283418
# Replaced 1141 values
# Replaced 158 values
# statistic=406.000, p-value=0.1327886745
# Replaced 1141 values
# Replaced 158 values
# statistic=407.000, p-value=0.0308178577
# Replaced 1141 values
# Replaced 158 values
# statistic=379.000, p-value=0.0077051838
# Replaced 1141 values
# Replaced 158 values
# statistic=392.000, p-value=0.0126510775
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0256113853
# Replaced 1141 values
# Replaced 158 values
# statistic=388.000, p-value=0.0076046111
# Replaced 1141 values
# Replaced 158 values
# statistic=362.000, p-value=0.0014295035
# Replaced 1141 values
# Replaced 158 values
# statistic=404.000, p-value=0.0127196488
# Replaced 1141 values
# Replaced 158 values
# statistic=399.000, p-value=0.0038174203
# Replaced 1141 values
# Replaced 158 values
# statistic=420.000, p-value=0.2117544519
# Replaced 1141 values
# Replaced 158 values
# statistic=408.000, p-value=0.0672302657
# p-value=0.0599162297
